# %%
import numpy as np 
import matplotlib.pyplot as plt 
  
  
grupos = ['Grupo 01', 'Grupo 02', 'Grupo 03', 'Grupo 04', 'Grupo 05', 'Grupo 06']
  
notas = [10, 50, 60, 30, 30, 70]
plt.bar(grupos, notas, color='red')

plt.title('Resultado Raspadinha')

plt.show()

# %%
import numpy as np 
import matplotlib.pyplot as plt 

grupos = ['Grupo 01', 'Grupo 02', 'Grupo 03', 'Grupo 04', 'Grupo 05', 'Grupo 06']
  
notas = [10, 50, 60, 30, 30, 70]
# margem_erro = [3,2,1,2,2]

# plt.barh(notas, grupos, color='red', xerr=margem_erro)

plt.ylabel('Grupos')
plt.xlabel('Notas em %')
plt.title('Notas raspadinha por grupo.')
# Out:
# Text(0.5, 1.0, 'Notas raspadinha por grupo.')
