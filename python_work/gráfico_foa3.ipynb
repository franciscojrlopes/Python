# %%
import numpy as np 
import matplotlib.pyplot as plt 
  
  
grupos = ['Grupo 01', 'Grupo 02', 'Grupo 03', 'Grupo 04', 'Grupo 05', 'Grupo 06']
  
notas = [10, 50, 60, 30, 30, 70]
plt.bar(grupos, notas, color='red')

plt.title('Resultado Raspadinha')

plt.show()

# %%
import numpy as np 
import matplotlib.pyplot as plt 

grupos = ['Grupo 01', 'Grupo 02', 'Grupo 03', 'Grupo 04', 'Grupo 05', 'Grupo 06']
  
notas = [10, 50, 60, 30, 30, 70]
margem_erro = [3,2,1,2,2]

plt.barh(notas, grupos, color='red', xerr=margem_erro)

plt.ylabel('Grupos')
plt.xlabel('Notas em %')
plt.title('Notas raspadinha por grupo.')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 9
#       6 notas = [10, 50, 60, 30, 30, 70]
#       7 margem_erro = [3,2,1,2,2]
# ----> 9 plt.barh(notas, grupos, color='red', xerr=margem_erro)
#      11 plt.ylabel('Grupos')
#      12 plt.xlabel('Notas em %')
#
# File c:\Users\fraro\OneDrive\Documentos\Estudos\Python\.venv\Lib\site-packages\matplotlib\pyplot.py:2768, in barh(y, width, height, left, align, data, **kwargs)
#    2757 @_copy_docstring_and_deprecators(Axes.barh)
#    2758 def barh(
#    2759     y: float | ArrayLike,
#    (...)
#    2766     **kwargs,
#    2767 ) -> BarContainer:
# -> 2768     return gca().barh(
#    2769         y,
#    2770         width,
#    2771         height=height,
#    2772         left=left,
#    2773         align=align,
#    2774         **({"data": data} if data is not None else {}),
#    2775         **kwargs,
#    2776     )
#
# File c:\Users\fraro\OneDrive\Documentos\Estudos\Python\.venv\Lib\site-packages\matplotlib\axes\_axes.py:2698, in Axes.barh(self, y, width, height, left, align, data, **kwargs)
#    2579 r"""
#    2580 Make a horizontal bar plot.
#    2581
#    (...)
#    2695 :doc:`/gallery/lines_bars_and_markers/horizontal_barchart_distribution`.
#    2696 """
#    2697 kwargs.setdefault('orientation', 'horizontal')
# -> 2698 patches = self.bar(x=left, height=height, width=width, bottom=y,
#    2699                    align=align, data=data, **kwargs)
#    2700 return patches
#
# File c:\Users\fraro\OneDrive\Documentos\Estudos\Python\.venv\Lib\site-packages\matplotlib\__init__.py:1478, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1475 @functools.wraps(func)
#    1476 def inner(ax, *args, data=None, **kwargs):
#    1477     if data is None:
# -> 1478         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1480     bound = new_sig.bind(ax, *args, **kwargs)
#    1481     auto_label = (bound.arguments.get(label_namer)
#    1482                   or bound.kwargs.get(label_namer))
#
# File c:\Users\fraro\OneDrive\Documentos\Estudos\Python\.venv\Lib\site-packages\matplotlib\axes\_axes.py:2550, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2546         ey = [b + 0.5 * h for b, h in zip(bottom, height)]
#    2548     error_kw.setdefault("label", '_nolegend_')
# -> 2550     errorbar = self.errorbar(ex, ey,
#    2551                              yerr=yerr, xerr=xerr,
#    2552                              fmt='none', **error_kw)
#    2553 else:
#    2554     errorbar = None
#
# File c:\Users\fraro\OneDrive\Documentos\Estudos\Python\.venv\Lib\site-packages\matplotlib\__init__.py:1478, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1475 @functools.wraps(func)
#    1476 def inner(ax, *args, data=None, **kwargs):
#    1477     if data is None:
# -> 1478         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1480     bound = new_sig.bind(ax, *args, **kwargs)
#    1481     auto_label = (bound.arguments.get(label_namer)
#    1482                   or bound.kwargs.get(label_namer))
#
# File c:\Users\fraro\OneDrive\Documentos\Estudos\Python\.venv\Lib\site-packages\matplotlib\axes\_axes.py:3667, in Axes.errorbar(self, x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, errorevery, capthick, **kwargs)
#    3665     np.broadcast_to(err, (2, len(dep)))
#    3666 except ValueError:
# -> 3667     raise ValueError(
#    3668         f"'{dep_axis}err' (shape: {np.shape(err)}) must be a "
#    3669         f"scalar or a 1D or (2, n) array-like whose shape matches "
#    3670         f"'{dep_axis}' (shape: {np.shape(dep)})") from None
#    3671 res = np.zeros(err.shape, dtype=bool)  # Default in case of nan
#    3672 if np.any(np.less(err, -err, out=res, where=(err == err))):
#    3673     # like err<0, but also works for timedelta and nan.
#
# ValueError: 'xerr' (shape: (5,)) must be a scalar or a 1D or (2, n) array-like whose shape matches 'x' (shape: (6,))
