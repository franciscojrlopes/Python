# %%
import pandas as pd

vendas_df = pd.read_csv(r'Contoso - Vendas - 2017.csv', encoding='latin-1', sep=';')
produtos_df = pd.read_csv(r'Contoso - Cadastro Produtos.csv', encoding='latin-1', sep=';')
lojas_df = pd.read_csv(r'Contoso - Lojas.csv', encoding='latin-1', sep=';')
clientes_df = pd.read_csv(r'Contoso - Clientes.csv', encoding='latin-1', sep=';')

display(vendas_df)
display(produtos_df)
display(lojas_df)
display(clientes_df)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                     2    01/01/2017    06/01/2017         5      308
# 2                     3    01/01/2017    01/01/2017         0      294
# 3                     4    01/01/2017    01/01/2017         0      251
# 4                     5    01/01/2017    07/01/2017         6       94
# ...                 ...           ...           ...       ...      ...
# 980637           980638    31/12/2017    31/12/2017         0      194
# 980638           980639    31/12/2017    06/01/2018         6       32
# 980639           980640    31/12/2017    03/01/2018         3      210
# 980640           980641    31/12/2017    31/12/2017         0       53
# 980641           980642    31/12/2017    31/12/2017         0      309
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %%
clientes_df = clientes_df[['Primeiro Nome', 'E-mail']]
produtos_df = produtos_df[['Fabricante', 'Nome da Marca']]
lojas_df = lojas_df[['País', 'Nome da Loja']]
display(clientes_df)
display(produtos_df)
display(lojas_df)
# Out:
#       Primeiro Nome                         E-mail
# 0            Garnet    glanfranchi0@mayoclinic.com
# 1           Lurette      lroseblade1@bigcartel.com
# 2           Glenden      gishchenko2@moonfruit.com
# 3             Baron    bjedrzejewsky3@e-recht24.de
# 4            Sheree       sbredbury4@sitemeter.com
# ...             ...                            ...
# 39499        Brandy    brandy0@adventure-works.com
# 39500        Alicia   alicia12@adventure-works.com
# 39501        Connie    connie4@adventure-works.com
# 39502         Shawn    shawn23@adventure-works.com
# 39503       Lindsey  lindsey10@adventure-works.com
#
# [39504 rows x 2 columns]
#             Fabricante     Nome da Marca
# 0         Contoso, Ltd           Contoso
# 1         Contoso, Ltd           Contoso
# 2         Contoso, Ltd           Contoso
# 3         Contoso, Ltd           Contoso
# 4         Contoso, Ltd           Contoso
# ...                ...               ...
# ...

# %%
import pandas as pd

#importando os arquivos

vendas_df = pd.read_csv(r'Contoso - Vendas  - 2017.csv', encoding='latin-1', sep=';')
produtos_df = pd.read_csv(r'Contoso - Cadastro Produtos.csv', encoding='latin-1', sep=';')
lojas_df = pd.read_csv(r'Contoso - Lojas.csv', encoding='latin-1', sep=';')
clientes_df = pd.read_csv(r'Contoso - Clientes.csv', encoding='latin-1', sep=';')
 
#limpando apenas as colunas que queremos

# clientes_df = clientes_df[['Primeiro Nome', 'E-mail']]
# produtos_df = produtos_df[['Fabricante', 'Nome da Marca']]
# lojas_df = lojas_df[['País', 'Nome da Loja']]

# #mesclando e renomeando os dataframes

# vendas_df = vendas_df.merge(produtos_df, on='Nome do Fabricante')
# vendas_df = vendas_df.merge(lojas_df, on='Nome do País')
# vendas_df = vendas_df.merge(clientes_df, on='Nome do Cliente').rename(columns={'E-mail': 'E-mail do Cliente'})
# display(vendas_df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 5
#       1 import pandas as pd
#       3 #importando os arquivos
# ----> 5 vendas_df = pd.read_csv(r'Contoso - Vendas  - 2017.csv', encoding='latin-1', sep=';')
#       6 produtos_df = pd.read_csv(r'Contoso - Cadastro Produtos.csv', encoding='latin-1', sep=';')
#       7 lojas_df = pd.read_csv(r'Contoso - Lojas.csv', encoding='latin-1', sep=';')
#
# ...
