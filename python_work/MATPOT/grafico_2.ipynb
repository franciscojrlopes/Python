# %%
pip install matplotlib
# Out:
# ...
#                                               0.0/8.1 MB ? eta -:--:--
#                                               0.1/8.1 MB 2.4 MB/s eta 0:00:04
#      -                                        0.4/8.1 MB 3.7 MB/s eta 0:00:03
#      ---                                      0.6/8.1 MB 4.3 MB/s eta 0:00:02
#      ---                                      0.8/8.1 MB 3.8 MB/s eta 0:00:02
#      ----                                     1.0/8.1 MB 4.4 MB/s eta 0:00:02
#      -----                                    1.2/8.1 MB 4.2 MB/s eta 0:00:02
#      -------                                  1.4/8.1 MB 4.3 MB/s eta 0:00:02
#      --------                                 1.7/8.1 MB 4.4 MB/s eta 0:00:02
#      --------                                 1.8/8.1 MB 4.1 MB/s eta 0:00:02
#      ---------                                1.9/8.1 MB 4.2 MB/s eta 0:00:02
#      ----------                               2.1/8.1 MB 4.1 MB/s eta 0:00:02
# ...

# %%
import matplotlib.pyplot as plt
  
meses = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']
vendas = [85, 90, 78, 92, 88, 96, 94, 98, 100, 102, 105, 108]
   
plt.plot(meses, vendas, marker= 'o')
plt.xlabel('Mês')
plt.ylabel('Vendas (em milhares)')
plt.title('Crescimento das Vendas ao Longo do Ano')
plt.show()

# %%
import matplotlib.pyplot as plt
  
meses = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']
vendas = [85, 90, 78, 92, 88, 96, 94, 98, 100, 102, 105, 108]
   
plt.plot(meses, vendas, marker= 'x')
plt.xlabel('Mês')
plt.ylabel('Vendas (em milhares)')
plt.title('Crescimento das Vendas ao Longo do Ano')
plt.show()

# %%
import matplotlib.pyplot as plt
  
meses = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']
vendas = [85, 90, 78, 92, 88, 96, 94, 98, 100, 102, 105, 108]
   
plt.plot(meses, vendas, marker= '*')
plt.xlabel('Mês')
plt.ylabel('Vendas (em milhares)')
plt.title('Crescimento das Vendas ao Longo do Ano')
plt.show()

# %%
import matplotlib.pyplot as plt
  
meses = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']
vendas = [85, 90, 78, 92, 88, 96, 94, 98, 100, 102, 105, 108]
   
plt.plot(meses, vendas, marker= 'o', markersize=10)
plt.xlabel('Mês')
plt.ylabel('Vendas (em milhares)')
plt.title('Crescimento das Vendas ao Longo do Ano')
plt.show()

# %%
import matplotlib.pyplot as plt
  
meses = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']
vendas = [85, 90, 78, 92, 88, 96, 94, 98, 100, 102, 105, 108]
   
plt.plot(meses, vendas, marker= 'o', linestyle='--')
plt.xlabel('Mês')
plt.ylabel('Vendas (em milhares)')
plt.title('Crescimento das Vendas ao Longo do Ano')
plt.show()

# %%
import matplotlib.pyplot as plt
  
meses = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']
vendas = [85, 90, 78, 92, 88, 96, 94, 98, 100, 102, 105, 108]
   
plt.plot(meses, vendas, marker= 'o', color='green')
plt.xlabel('Mês')
plt.ylabel('Vendas (em milhares)')
plt.title('Crescimento das Vendas ao Longo do Ano')
plt.show()

# %%
import matplotlib.pyplot as plt
  
meses = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']
vendas = [85, 90, 78, 92, 88, 96, 94, 98, 100, 102, 105, 108]
   
plt.plot(meses, vendas, marker= '*', color='red')
plt.xlabel('Mês')
plt.ylabel('Vendas (em milhares)')
plt.title('Crescimento das Vendas ao Longo do Ano')
plt.show()

# %%
import matplotlib.pyplot as plt
  
meses = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']
vendas = [85, 90, 78, 92, 88, 96, 94, 98, 100, 102, 105, 108]
   
plt.plot(meses, vendas, marker= '*', color='red', markersize=10)
plt.xlabel('Mês')
plt.ylabel('Vendas (em milhares)')
plt.title('Crescimento das Vendas ao Longo do Ano')
plt.show()

# %%
import matplotlib.pyplot as plt
  
meses = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']
vendas = [85, 90, 78, 92, 88, 96, 94, 98, 100, 102, 105, 108]
   
plt.plot(meses, vendas, marker= 'x', color='black', markersize=10)
plt.xlabel('Mês')
plt.ylabel('Vendas (em milhares)')
plt.title('Crescimento das Vendas ao Longo do Ano')
plt.show()
