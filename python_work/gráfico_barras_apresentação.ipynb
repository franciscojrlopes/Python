# %%
import matplotlib.pyplot as plt
 
produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

plt.bar (produtos, quantidades)
plt.show()

# %%
import matplotlib.pyplot as plt
 
produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

plt.barh (produtos, quantidades)
plt.show()

# %%
import matplotlib.pyplot as plt
 
produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

barras = plt.barh (produtos, quantidades)
plt.bar_label(barras, labels=quantidades )
plt.show()

# %%
import matplotlib.pyplot as plt
 
produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

barras = plt.barh (produtos, quantidades)
plt.bar_label(barras, labels=quantidades )
plt.box(False)
plt.xticks([])
plt.show()

# %%
import matplotlib.pyplot as plt
 
produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

barras = plt.barh (produtos, quantidades)
plt.bar_label(barras, labels=quantidades, padding=3, fontweight= 'bold', fontsize=10)
plt.box(False)
plt.xticks([])
plt.show()

# %%
import matplotlib.pyplot as plt
 
produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

barras = plt.barh (produtos, quantidades)
plt.bar_label(barras, labels=quantidades, padding=-30, fontweight= 'bold', fontsize=10)
plt.box(False)
plt.xticks([])
plt.show()

# %%
import matplotlib.pyplot as plt
 
produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

barras = plt.barh (produtos, quantidades)
plt.bar_label(barras, labels=quantidades, padding=3, fontweight= 'bold', fontsize=10)
plt.box(False)
plt.xticks([])
plt.tick_params(axis='y', length=0)
plt.show()

# %%
import matplotlib.pyplot as plt
 
produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

barras = plt.barh (produtos, quantidades)
plt.bar_label(barras, labels=quantidades, padding=3, fontweight= 'bold', fontsize=10)
plt.title('Quantidade de Produtos Vendidos')
plt.box(False)
plt.xticks([])
plt.tick_params(axis='y', length=0)
plt.show()

# %%
barras
# Out:
# <BarContainer object of 5 artists>

# %%
for i, barra in enumerate(barras):
    print(i, barra)
# Out:
# 0 Rectangle(xy=(0, -0.4), width=23, height=0.8, angle=0)
# 1 Rectangle(xy=(0, 0.6), width=45, height=0.8, angle=0)
# 2 Rectangle(xy=(0, 1.6), width=17, height=0.8, angle=0)
# 3 Rectangle(xy=(0, 2.6), width=30, height=0.8, angle=0)
# 4 Rectangle(xy=(0, 3.6), width=37, height=0.8, angle=0)

# %%
import matplotlib.pyplot as plt
from cycler import cycler
cores = plt.get_cmap('Pastel2').colors
ciclo_cores = cycler('color', cores)
plt.rc('axes', prop_cycle=ciclo_cores)
produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

barras = plt.barh (produtos, quantidades)
plt.bar_label(barras, labels=quantidades, padding=3, fontweight= 'bold', fontsize=10)
for i, barra in enumerate(barras):
    if i != quantidades.index(max(quantidades)):
        barras[1].set_color([2])

plt.title('Quantidade de Produtos Vendidos')
plt.box(False)
plt.xticks([])
plt.tick_params(axis='y', length=0)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[75], line 13
#      11 for i, barra in enumerate(barras):
#      12     if i != quantidades.index(max(quantidades)):
# ---> 13         barras[1].set_color([2])
#      15 plt.title('Quantidade de Produtos Vendidos')
#      16 plt.box(False)
#
# File c:\Users\fraro\OneDrive\Documentos\Estudos\Python\.venv\Lib\site-packages\matplotlib\patches.py:371, in Patch.set_color(self, c)
#     358 def set_color(self, c):
#     359     """
#     360     Set both the edgecolor and the facecolor.
#     361
#    (...)
#     369         For setting the edge or face color individually.
#     370     """
# --> 371     self.set_facecolor(c)
#     372     self.set_edgecolor(c)
#
# File c:\Users\fraro\OneDrive\Documentos\Estudos\Python\.venv\Lib\site-packages\matplotlib\patches.py:356, in Patch.set_facecolor(self, color)
#     348 """
#     349 Set the patch face color.
#     350
#    (...)
#     353 color : color or None
#     354 """
#     355 self._original_facecolor = color
# --> 356 self._set_facecolor(color)
#
# File c:\Users\fraro\OneDrive\Documentos\Estudos\Python\.venv\Lib\site-packages\matplotlib\patches.py:344, in Patch._set_facecolor(self, color)
#     342     color = mpl.rcParams['patch.facecolor']
#     343 alpha = self._alpha if self._fill else 0
# --> 344 self._facecolor = colors.to_rgba(color, alpha)
#     345 self.stale = True
#
# File c:\Users\fraro\OneDrive\Documentos\Estudos\Python\.venv\Lib\site-packages\matplotlib\colors.py:302, in to_rgba(c, alpha)
#     300     rgba = None
#     301 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 302     rgba = _to_rgba_no_colorcycle(c, alpha)
#     303     try:
#     304         _colors_full_map.cache[c, alpha] = rgba
#
# File c:\Users\fraro\OneDrive\Documentos\Estudos\Python\.venv\Lib\site-packages\matplotlib\colors.py:393, in _to_rgba_no_colorcycle(c, alpha)
#     391     raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     392 if len(c) not in [3, 4]:
# --> 393     raise ValueError("RGBA sequence should have length 3 or 4")
#     394 if not all(isinstance(x, Real) for x in c):
#     395     # Checks that don't work: `map(float, ...)`, `np.array(..., float)` and
#     396     # `np.array(...).astype(float)` would all convert "0.5" to 0.5.
#     397     raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#
# ValueError: RGBA sequence should have length 3 or 4
