# %%
import matplotlib.pyplot as plt
 
produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

plt.bar (produtos, quantidades)
plt.show()

# %%
import matplotlib.pyplot as plt
 
produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

plt.barh (produtos, quantidades)
plt.show()

# %%
import matplotlib.pyplot as plt
 
produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

barras = plt.barh (produtos, quantidades)
plt.bar_label(barras, labels=quantidades )
plt.show()

# %%
import matplotlib.pyplot as plt
 
produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

barras = plt.barh (produtos, quantidades)
plt.bar_label(barras, labels=quantidades )
plt.box(False)
plt.xticks([])
plt.show()

# %%
import matplotlib.pyplot as plt
 
produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

barras = plt.barh (produtos, quantidades)
plt.bar_label(barras, labels=quantidades, padding=3, fontweight= 'bold', fontsize=10)
plt.box(False)
plt.xticks([])
plt.show()

# %%
import matplotlib.pyplot as plt
 
produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

barras = plt.barh (produtos, quantidades)
plt.bar_label(barras, labels=quantidades, padding=-30, fontweight= 'bold', fontsize=10)
plt.box(False)
plt.xticks([])
plt.show()

# %%
import matplotlib.pyplot as plt
 
produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

barras = plt.barh (produtos, quantidades)
plt.bar_label(barras, labels=quantidades, padding=3, fontweight= 'bold', fontsize=10)
plt.box(False)
plt.xticks([])
plt.tick_params(axis='y', length=0)
plt.show()

# %%
import matplotlib.pyplot as plt
 
produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

barras = plt.barh (produtos, quantidades)
plt.bar_label(barras, labels=quantidades, padding=3, fontweight= 'bold', fontsize=10)
plt.title('Quantidade de Produtos Vendidos')
plt.box(False)
plt.xticks([])
plt.tick_params(axis='y', length=0)
plt.show()

# %%
barras
# Out:
# <BarContainer object of 5 artists>

# %%
for i, barra in enumerate(barras):
    print(i, barra)
# Out:
# 0 Rectangle(xy=(0, -0.4), width=23, height=0.8, angle=0)
# 1 Rectangle(xy=(0, 0.6), width=45, height=0.8, angle=0)
# 2 Rectangle(xy=(0, 1.6), width=17, height=0.8, angle=0)
# 3 Rectangle(xy=(0, 2.6), width=30, height=0.8, angle=0)
# 4 Rectangle(xy=(0, 3.6), width=37, height=0.8, angle=0)

# %%
print(min(quantidades))
print(max(quantidades))
print(quantidades.index(max(quantidades)))
# Out:
# 17
# 45
# 1

# %%
import matplotlib.pyplot as plt
from cycler import cycler
cores = plt.get_cmap('Pastel2').colors
ciclo_cores = cycler('color', cores)
plt.rc('axes', prop_cycle=ciclo_cores)
produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

barras = plt.barh (produtos, quantidades)
plt.bar_label(barras, labels=quantidades, padding=3, fontweight= 'bold', fontsize=10)

plt.box(False)
plt.xticks([])
plt.tick_params(axis='y', length=0)
for i, barra in enumerate(barras):
    if i != quantidades.index(max(quantidades)):
        barras[1].set_color(cores[1])
        

plt.title('Quantidade de Produtos Vendidos')

plt.show()

# %%
import matplotlib.pyplot as plt
from cycler import cycler
cores = plt.get_cmap('Pastel2').colors
ciclo_cores = cycler('color', cores)
plt.rc('axes', prop_cycle=ciclo_cores)
produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

barras = plt.barh (produtos, quantidades)
plt.bar_label(barras, labels=quantidades, padding=3, fontweight= 'bold', fontsize=10)

plt.box(False)
plt.xticks([])
plt.tick_params(axis='y', length=0)
for i, barra in enumerate(barras):
    if i != quantidades.index(max(quantidades)):
        barras[i].set_color('red')
        

plt.title('Quantidade de Produtos Vendidos')

plt.show()

# %%
import matplotlib.pyplot as plt
from cycler import cycler
cores = plt.get_cmap('Pastel2').colors
ciclo_cores = cycler('color', cores)
plt.rc('axes', prop_cycle=ciclo_cores)
produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

barras = plt.barh (produtos, quantidades)
plt.bar_label(barras, labels=quantidades, padding=3, fontweight= 'bold', fontsize=10)

plt.box(False)
plt.xticks([])
plt.tick_params(axis='y', length=0)
for i, barra in enumerate(barras):
    if i != quantidades.index(max(quantidades)):
        barras[i].set_color('red')
        barras[i].set_alpha(0.3)

plt.title('Quantidade de Produtos Vendidos')

plt.show()

# %%
import matplotlib.pyplot as plt
from cycler import cycler
cores = plt.get_cmap('Pastel2').colors
ciclo_cores = cycler('color', cores)
plt.rc('axes', prop_cycle=ciclo_cores)
produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]
rotulos = [valor if valor ==  max(quantidades) else '' for valor in quantidades]

barras = plt.barh (produtos, quantidades)
plt.bar_label(barras, labels=rotulos, padding=3, fontweight= 'bold', fontsize=10)

plt.box(False)
plt.xticks([])
plt.tick_params(axis='y', length=0)
for i, barra in enumerate(barras):
    if i != quantidades.index(max(quantidades)):
        barras[i].set_color('red')
        barras[i].set_alpha(0.2)
        

plt.title('Quantidade de Produtos Vendidos')

plt.show()

# %%
import matplotlib.pyplot as plt
from cycler import cycler
cores = plt.get_cmap('Pastel2').colors
ciclo_cores = cycler('color', cores)
plt.rc('axes', prop_cycle=ciclo_cores)
produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]
rotulos = [valor if valor ==  min(quantidades) else '' for valor in quantidades]

barras = plt.barh (produtos, quantidades)
plt.bar_label(barras, labels=rotulos, padding=3, fontweight= 'bold', fontsize=10)

plt.box(False)
plt.xticks([])
plt.tick_params(axis='y', length=0)
for i, barra in enumerate(barras):
    if i != quantidades.index(min(quantidades)):
        barras[i].set_color('green')
        barras[i].set_alpha(1.0)
        

plt.title('Quantidade de Produtos Vendidos')

plt.show()

# %%
import matplotlib.pyplot as plt
from cycler import cycler
cores = plt.get_cmap('Pastel2').colors
ciclo_cores = cycler('color', cores)
plt.rc('axes', prop_cycle=ciclo_cores)
produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]
rotulos = [valor if valor ==  min(quantidades) else '' for valor in quantidades]

barras = plt.barh (produtos, quantidades)
plt.bar_label(barras, labels=rotulos, padding=3, fontweight= 'bold', fontsize=10)

plt.box(False)
plt.xticks([])
plt.tick_params(axis='y', length=0)
for i, barra in enumerate(barras):
    if i != quantidades.index(min(quantidades)):
        barras[i].set_color('orange')
        barras[i].set_alpha(0.3)
        

plt.title('Quantidade de Produtos Vendidos')

plt.show()
