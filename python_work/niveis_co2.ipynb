# %% [markdown]
# 1. Identificando Locais de Risco\n",
#
#     (Não conhecemos muito dos números e indicadores reais, esse é um exercício imaginário para treinarmos com um cenário mais prático)
#
#     Digamos que você está construindo um programa para identificar níveis de CO2 (gás carbônico) em determinados locais para evitar potenciais acidentes. Em cada um desses locais a sua empresa tem 5 sensores que captam o nível de CO2 do local.
#
#     Os níveis normais de CO2 são em média 350. O nível de CO2 de um local é dado pela média captada pelos 5 sensores.
#
#     Isso significa que se tivermos os 5 sensores do Rio de Janeiro marcando: 350, 400, 450, 350, 300, o nível de CO2 do Rio de Janeiro será dado por: (350 + 400 + 450 + 350 + 300) / 5 = 370.
#
#     Caso o nível seja maior do que 450, um aviso deve ser exibido pelo seu programa dizendo, por exemplo: Rio de Janeiro está com níveis altíssimos de CO2 (490), chamar equipe especializada para verificar a região.
#
#     Os resultados dos sensores são monitorados frequentemente e são dados para o sistema em forma de dicionário:

# %%
niveis_co2 = {
        'AC': [325,405,429,486,402],
        'AL': [492,495,310,407,388],
        'AP': [507,503,368,338,400],
        'AM': [429,456,352,377,363],
        'BA': [321,508,372,490,412],
        'CE': [424,328,425,516,480],
        'ES': [449,506,461,337,336],
        'GO': [425,460,385,485,460],
        'MA': [361,310,344,425,490],
        'MT': [358,402,425,386,379],
        'MS': [324,357,441,405,427],
        'MG': [345,367,391,427,516],
        'PA': [479,514,392,493,329],
        'PB': [418,499,317,302,476],
        'PR': [420,508,419,396,327],
        'PE': [404,444,495,320,343],
        'PI': [513,513,304,377,475],
        'RJ': [502,481,492,502,506],
        'RN': [446,437,519,356,317],
        'RS': [427,518,459,317,321],
        'RO': [517,466,512,326,458],
        'RR': [466,495,469,495,310],
        'SC': [495,436,382,483,479],
        'SP': [495,407,362,389,317],
        'SE': [508,351,334,389,418],
        'TO': [339,490,304,488,419],
        'DF': [376,516,320,310,518],
    } 

for estado in niveis_co2:
    print(niveis_co2[estado])
# Out:
# [325, 405, 429, 486, 402]
# [492, 495, 310, 407, 388]
# [507, 503, 368, 338, 400]
# [429, 456, 352, 377, 363]
# [321, 508, 372, 490, 412]
# [424, 328, 425, 516, 480]
# [449, 506, 461, 337, 336]
# [425, 460, 385, 485, 460]
# [361, 310, 344, 425, 490]
# [358, 402, 425, 386, 379]
# [324, 357, 441, 405, 427]
# [345, 367, 391, 427, 516]
# [479, 514, 392, 493, 329]
# [418, 499, 317, 302, 476]
# [420, 508, 419, 396, 327]
# [404, 444, 495, 320, 343]
# [513, 513, 304, 377, 475]
# [502, 481, 492, 502, 506]
# [446, 437, 519, 356, 317]
# [427, 518, 459, 317, 321]
# [517, 466, 512, 326, 458]
# [466, 495, 469, 495, 310]
# [495, 436, 382, 483, 479]
# [495, 407, 362, 389, 317]
# [508, 351, 334, 389, 418]
# [339, 490, 304, 488, 419]
# [376, 516, 320, 310, 518]

# %%
niveis_co2 = {
        'AC': [325,405,429,486,402],
        'AL': [492,495,310,407,388],
        'AP': [507,503,368,338,400],
        'AM': [429,456,352,377,363],
        'BA': [321,508,372,490,412],
        'CE': [424,328,425,516,480],
        'ES': [449,506,461,337,336],
        'GO': [425,460,385,485,460],
        'MA': [361,310,344,425,490],
        'MT': [358,402,425,386,379],
        'MS': [324,357,441,405,427],
        'MG': [345,367,391,427,516],
        'PA': [479,514,392,493,329],
        'PB': [418,499,317,302,476],
        'PR': [420,508,419,396,327],
        'PE': [404,444,495,320,343],
        'PI': [513,513,304,377,475],
        'RJ': [502,481,492,502,506],
        'RN': [446,437,519,356,317],
        'RS': [427,518,459,317,321],
        'RO': [517,466,512,326,458],
        'RR': [466,495,469,495,310],
        'SC': [495,436,382,483,479],
        'SP': [495,407,362,389,317],
        'SE': [508,351,334,389,418],
        'TO': [339,490,304,488,419],
        'DF': [376,516,320,310,518],
    } 

for estado in niveis_co2:
    # print(niveis_co2[estado])
    qtde_sensores = len(niveis_co2[estado])
    total_co2 = sum(niveis_co2[estado])
    media_co2 = total_co2 / qtde_sensores
    if  media_co2 > 450:
        print('{} está com níveis altíssimos de CO2 ({}), chamar equipe especializada para verificar a região.'.format(estado, media_co2))
# Out:
# RJ está com níveis altíssimos de CO2 (496.6), chamar equipe especializada para verificar a região.
# RO está com níveis altíssimos de CO2 (455.8), chamar equipe especializada para verificar a região.
# SC está com níveis altíssimos de CO2 (455.0), chamar equipe especializada para verificar a região.

# %%
niveis_co2 = {
        'AC': [325,405,429,486,402],
        'AL': [492,495,310,407,388],
        'AP': [507,503,368,338,400],
        'AM': [429,456,352,377,363],
        'BA': [321,508,372,490,412],
        'CE': [424,328,425,516,480],
        'ES': [449,506,461,337,336],
        'GO': [425,460,385,485,460],
        'MA': [361,310,344,425,490],
        'MT': [358,402,425,386,379],
        'MS': [324,357,441,405,427],
        'MG': [345,367,391,427,516],
        'PA': [479,514,392,493,329],
        'PB': [418,499,317,302,476],
        'PR': [420,508,419,396,327],
        'PE': [404,444,495,320,343],
        'PI': [513,513,304,377,475],
        'RJ': [502,481,492,502,506],
        'RN': [446,437,519,356,317],
        'RS': [427,518,459,317,321],
        'RO': [517,466,512,326,458],
        'RR': [466,495,469,495,310],
        'SC': [495,436,382,483,479],
        'SP': [495,407,362,389,317],
        'SE': [508,351,334,389,418],
        'TO': [339,490,304,488,419],
        'DF': [376,516,320,310,518],
    } 

for estado in niveis_co2:
    # print(niveis_co2[estado])
    qtde_sensores = len(niveis_co2[estado])
    total_co2 = sum(niveis_co2[estado])
    media_co2 = total_co2 / qtde_sensores
    if  media_co2 > 380:
        print('{} está com níveis altíssimos de CO2 ({}), chamar equipe especializada para verificar a região.'.format(estado, media_co2))
# Out:
# AC está com níveis altíssimos de CO2 (409.4), chamar equipe especializada para verificar a região.
# AL está com níveis altíssimos de CO2 (418.4), chamar equipe especializada para verificar a região.
# AP está com níveis altíssimos de CO2 (423.2), chamar equipe especializada para verificar a região.
# AM está com níveis altíssimos de CO2 (395.4), chamar equipe especializada para verificar a região.
# BA está com níveis altíssimos de CO2 (420.6), chamar equipe especializada para verificar a região.
# CE está com níveis altíssimos de CO2 (434.6), chamar equipe especializada para verificar a região.
# ES está com níveis altíssimos de CO2 (417.8), chamar equipe especializada para verificar a região.
# GO está com níveis altíssimos de CO2 (443.0), chamar equipe especializada para verificar a região.
# MA está com níveis altíssimos de CO2 (386.0), chamar equipe especializada para verificar a região.
# MT está com níveis altíssimos de CO2 (390.0), chamar equipe especializada para verificar a região.
# MS está com níveis altíssimos de CO2 (390.8), chamar equipe especializada para verificar a região.
# MG está com níveis altíssimos de CO2 (409.2), chamar equipe especializada para verificar a região.
# PA está com níveis altíssimos de CO2 (441.4), chamar equipe especializada para verificar a região.
# PB está com níveis altíssimos de CO2 (402.4), chamar equipe especializada para verificar a região.
# PR está com níveis altíssimos de CO2 (414.0), chamar equipe especializada para verificar a região.
# PE está com níveis altíssimos de CO2 (401.2), chamar equipe especializada para verificar a região.
# PI está com níveis altíssimos de CO2 (436.4), chamar equipe especializada para verificar a região.
# RJ está com níveis altíssimos de CO2 (496.6), chamar equipe especializada para verificar a região.
# RN está com níveis altíssimos de CO2 (415.0), chamar equipe especializada para verificar a região.
# RS está com níveis altíssimos de CO2 (408.4), chamar equipe especializada para verificar a região.
# RO está com níveis altíssimos de CO2 (455.8), chamar equipe especializada para verificar a região.
# RR está com níveis altíssimos de CO2 (447.0), chamar equipe especializada para verificar a região.
# SC está com níveis altíssimos de CO2 (455.0), chamar equipe especializada para verificar a região.
# SP está com níveis altíssimos de CO2 (394.0), chamar equipe especializada para verificar a região.
# SE está com níveis altíssimos de CO2 (400.0), chamar equipe especializada para verificar a região.
# TO está com níveis altíssimos de CO2 (408.0), chamar equipe especializada para verificar a região.
# DF está com níveis altíssimos de CO2 (408.0), chamar equipe especializada para verificar a região.

# %%
niveis_co2 = {
        'AC': [325,405,429,486,402],
        'AL': [492,495,310,407,388],
        'AP': [507,503,368,338,400],
        'AM': [429,456,352,377,363],
        'BA': [321,508,372,490,412],
        'CE': [424,328,425,516,480],
        'ES': [449,506,461,337,336],
        'GO': [425,460,385,485,460],
        'MA': [361,310,344,425,490],
        'MT': [358,402,425,386,379],
        'MS': [324,357,441,405,427],
        'MG': [345,367,391,427,516],
        'PA': [479,514,392,493,329],
        'PB': [418,499,317,302,476],
        'PR': [420,508,419,396,327],
        'PE': [404,444,495,320,343],
        'PI': [513,513,304,377,475],
        'RJ': [502,481,492,502,506],
        'RN': [446,437,519,356,317],
        'RS': [427,518,459,317,321],
        'RO': [517,466,512,326,458],
        'RR': [466,495,469,495,310],
        'SC': [495,436,382,483,479],
        'SP': [495,407,362,389,317],
        'SE': [508,351,334,389,418],
        'TO': [339,490,304,488,419],
        'DF': [376,516,320,310,518],
    } 

for estado in niveis_co2:
    # print(niveis_co2[estado])
    qtde_sensores = len(niveis_co2[estado])
    total_co2 = sum(niveis_co2[estado])
    media_co2 = total_co2 / qtde_sensores
    if  media_co2 > 488:
        print('{} está com níveis altíssimos de CO2 ({}), chamar equipe especializada para verificar a região.'.format(estado, media_co2))
# Out:
# RJ está com níveis altíssimos de CO2 (496.6), chamar equipe especializada para verificar a região.
