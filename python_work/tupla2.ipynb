# %%
vendas = ('Francisco', '25/10/2023', 3000, 'Representante Comercial')
print(vendas)
nome = vendas[0]
data = vendas[1]
venda_período = vendas[2]
cargo = vendas[3]
print(cargo)
# Out:
# ('Francisco', '25/10/2023', 3000, 'Representante Comercial')
# Representante Comercial

# %%
vendas = ('Francisco', '25/10/2023', 3000, 'Representante Comercial')

nome, data, venda_período, cargo = vendas
print(nome)
# Out:
# Francisco
