# %%
# from chave import chave_api
chave_api = 'YPHK24D9ZH4R633F'
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_WEEKLY&symbol=IBM&apikey=demo'
r = requests.get(url)
data = r.json()
import pprint
pprint.pprint(data)
# Out:
# {'Meta Data': {'1. Information': 'Weekly Prices (open, high, low, close) and '
#                                  'Volumes',
#                '2. Symbol': 'IBM',
#                '3. Last Refreshed': '2024-02-23',
#                '4. Time Zone': 'US/Eastern'},
#  'Weekly Time Series': {'1999-11-12': {'1. open': '90.5000',
#                                        '2. high': '97.5000',
#                                        '3. low': '90.5000',
#                                        '4. close': '95.8700',
#                                        '5. volume': '43569700'},
#                         '1999-11-19': {'1. open': '96.0000',
#                                        '2. high': '105.1200',
#                                        '3. low': '92.6200',
#                                        '4. close': '103.9400',
#                                        '5. volume': '61550800'},
#                         '1999-11-26': {'1. open': '105.5000',
# ...

# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_WEEKLY&symbol=IBM&apikey=demo'
r = requests.get(url)
data = r.json()
import pprint
pprint.pprint(data['Meta Data'])
# Out:
# {'1. Information': 'Weekly Prices (open, high, low, close) and Volumes',
#  '2. Symbol': 'IBM',
#  '3. Last Refreshed': '2024-02-23',
#  '4. Time Zone': 'US/Eastern'}

# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = f'https://www.alphavantage.co/query?function=TIME_SERIES_WEEKLY&symbol=IBM&apikey={chave_api}'
r = requests.get(url)
data = r.json()
import pprint
pprint.pprint(data['Meta Data'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 8
#       6 data = r.json()
#       7 import pprint
# ----> 8 pprint.pprint(data['Meta Data'])
#
# KeyError: 'Meta Data'

# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = f'https://www.alphavantage.co/query?function=TIME_SERIES_WEEKLY&symbol=IBM&apikey={chave_api}'
r = requests.get(url)
data = r.json()
import pprint
pprint.pprint(data)
# Out:
# {'Information': 'Thank you for using Alpha Vantage! Our standard API rate '
#                 'limit is 25 requests per day. Please subscribe to any of the '
#                 'premium plans at https://www.alphavantage.co/premium/ to '
#                 'instantly remove all daily rate limits.'}

# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = f'https://www.alphavantage.co/query?function=TIME_SERIES_WEEKLY&symbol=GOOG&apikey={chave_api}'
r = requests.get(url)
data = r.json()
import pprint
pprint.pprint(data)
# Out:
# {'Information': 'Thank you for using Alpha Vantage! Our standard API rate '
#                 'limit is 25 requests per day. Please subscribe to any of the '
#                 'premium plans at https://www.alphavantage.co/premium/ to '
#                 'instantly remove all daily rate limits.'}

# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = f'https://www.alphavantage.co/query?function=TIME_SERIES_WEEKLY&symbol=GOOG&apikey={chave_api}'
r = requests.get(url)
data = r.json()
import pprint
# pprint.pprint(data)
print(data)
# Out:
# {'Information': 'Thank you for using Alpha Vantage! Our standard API rate limit is 25 requests per day. Please subscribe to any of the premium plans at https://www.alphavantage.co/premium/ to instantly remove all daily rate limits.'}

# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = f'https://www.alphavantage.co/query?function=TIME_SERIES_WEEKLY&symbol=ITUB4.SAO&apikey={chave_api}'
r = requests.get(url)
data = r.json()
import pprint
# pprint.pprint(data)
print(data)
# Out:
# {'Information': 'Thank you for using Alpha Vantage! Our standard API rate limit is 25 requests per day. Please subscribe to any of the premium plans at https://www.alphavantage.co/premium/ to instantly remove all daily rate limits.'}

# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = f'https://www.alphavantage.co/query?function=TIME_SERIES_WEEKLY&symbol=ITUB3.SAO&apikey={chave_api}'
r = requests.get(url)
data = r.json()
import pprint
# pprint.pprint(data)
print(data)
# Out:
# {'Meta Data': {'1. Information': 'Weekly Prices (open, high, low, close) and Volumes', '2. Symbol': 'ITUB3.SAO', '3. Last Refreshed': '2024-02-23', '4. Time Zone': 'US/Eastern'}, 'Weekly Time Series': {'2024-02-23': {'1. open': '29.7300', '2. high': '31.0200', '3. low': '29.3200', '4. close': '29.6500', '5. volume': '4841200'}, '2024-02-16': {'1. open': '29.3300', '2. high': '29.8000', '3. low': '29.0200', '4. close': '29.7300', '5. volume': '1105500'}, '2024-02-09': {'1. open': '27.9500', '2. high': '29.6800', '3. low': '27.7800', '4. close': '29.3400', '5. volume': '4136500'}, '2024-02-02': {'1. open': '28.0200', '2. high': '28.3000', '3. low': '27.5800', '4. close': '27.9500', '5. volume': '1631100'}, '2024-01-26': {'1. open': '28.0000', '2. high': '28.1700', '3. low': '27.3900', '4. close': '28.0200', '5. volume': '3030900'}, '2024-01-19': {'1. open': '28.2900', '2. high': '28.4600', '3. low': '27.7200', '4. close': '28.0000', '5. volume': '1923300'}, '2024-01-12': {'1. open': '2
# ...

# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = f'https://www.alphavantage.co/query?function=TIME_SERIES_WEEKLY&symbol=ITUB4.SAO&apikey={chave_api}&datatype=csv'
r = requests.get(url)
# data = r.json()
import pprint
# pprint.pprint(data)
print(r.text)
# Out:
# timestamp,open,high,low,close,volume
# 2024-02-23,34.5800,35.9500,33.8700,34.2600,155873600
# 2024-02-16,34.2000,34.7900,34.1200,34.5400,63982000
# 2024-02-09,32.8800,34.8700,32.8000,34.2900,208806700
# 2024-02-02,32.7100,33.3300,32.1900,32.7400,99244200
# 2024-01-26,32.9500,33.1700,31.9700,32.8100,111140500
# 2024-01-19,33.3700,33.5700,32.7100,32.9400,126805600
# 2024-01-12,33.5200,33.6700,32.7900,33.3900,85600900
# 2024-01-05,33.8900,33.8900,32.7000,33.7000,91790700
# 2023-12-28,33.3700,33.9700,33.2300,33.9700,53867200
# 2023-12-22,32.8300,33.5400,32.4800,33.3100,128989300
# 2023-12-15,31.8500,33.0400,31.3900,32.7300,152029300
# 2023-12-08,31.3200,32.1200,31.2100,32.0200,100873800
# 2023-12-01,30.8300,31.6800,30.4800,31.5000,134874500
# 2023-11-24,30.4800,31.2300,30.2500,30.6800,122332900
# 2023-11-17,29.4800,30.5900,29.1700,30.4500,122691800
# 2023-11-10,28.0500,29.8700,27.8800,29.5900,152825100
# 2023-11-03,27.4900,28.1100,26.6600,27.9300,102037500
# ...

# %%
import pandas as pd
from io import StringIO
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = f'https://www.alphavantage.co/query?function=TIME_SERIES_WEEKLY&symbol=ITUB4.SAO&apikey={chave_api}&datatype=csv'
r = requests.get(url)

tabela = pd.read_csv(StringIO(r.text))
display(tabela)
# Out:
#        timestamp      open      high       low     close     volume
# 0     2024-02-23   34.5800   35.9500   33.8700   34.2600  155873600
# 1     2024-02-16   34.2000   34.7900   34.1200   34.5400   63982000
# 2     2024-02-09   32.8800   34.8700   32.8000   34.2900  208806700
# 3     2024-02-02   32.7100   33.3300   32.1900   32.7400   99244200
# 4     2024-01-26   32.9500   33.1700   31.9700   32.8100  111140500
# ...          ...       ...       ...       ...       ...        ...
# 1001  2005-02-11  430.0002  438.0024  426.9987  432.8991  637399594
# 1002  2005-02-04  384.4994  440.0015  384.4994  438.0024  894557778
# 1003  2005-01-28  386.9996  392.0003  375.5004  378.9974  864360715
# 1004  2005-01-21  397.9007  402.9920  386.0997  389.5001  847329571
# 1005  2005-01-14  390.0074  398.0096  383.9981  398.0096  942510713
#
# [1006 rows x 6 columns]

# %%
ações = ['ITUB4', 'ABEV3', 'BBAS3']

url = f'https://www.alphavantage.co/query?function=TIME_SERIES_WEEKLY&symbol=ABEV3.SAO&apikey={chave_api}&datatype=csv'
r = requests.get(url)

tabela = pd.read_csv(StringIO(r.text))
display(tabela)
# Out:
#       timestamp   open   high    low  close     volume
# 0    2024-02-23  12.77  13.09  12.65  12.89   85068900
# 1    2024-02-16  12.88  13.02  12.75  12.76   65150700
# 2    2024-02-09  13.08  13.31  12.81  12.95  122818800
# 3    2024-02-02  13.16  13.29  12.90  13.07  107962400
# 4    2024-01-26  13.38  13.45  13.14  13.20   68587500
# ..          ...    ...    ...    ...    ...        ...
# 558  2013-06-21  77.20  79.74  75.06  77.81    1365200
# 559  2013-06-14  78.00  79.56  75.69  76.70    1025000
# 560  2013-06-07  82.00  82.60  77.97  78.00    1225600
# 561  2013-05-31  83.84  85.57  79.77  82.05    1224600
# 562  2013-05-24  86.02  86.77  83.06  83.85     934500
#
# [563 rows x 6 columns]

# %% [markdown]
# Mudr pra globl quote:

# %%
ações = ['ITUB4', 'ABEV3', 'BBAS3']

url = f'https://www.alphavantage.co/query?function=GLOBAL_QUOTE&symbol&symbol=ABEV3.SAO&apikey={chave_api}&datatype=csv'
r = requests.get(url)

tabela = pd.read_csv(StringIO(r.text))
display(tabela)
# Out:
#                                                    {
# 0      "Information": "Thank you for using Alpha ...
# 1                                                  }

# %%
acoes = ['ITUB4', 'ABEV3', 'BBAS3']
compilada = pd.DataFrame()
for acao in acoes:
    
    url = f'https://www.alphavantage.co/query?function=GLOBAL_QUOTE&symbol&symbol={acao}.SAO&apikey={chave_api}&datatype=csv'
    r = requests.get(url)

    tabela = pd.read_csv(StringIO(r.text))
    lista_tabelas = [compilada, tabela]
    compilada = pd.concat(lista_tabelas)
    display(compilada)
# Out:
#                                                    {
# 0      "Information": "Thank you for using Alpha ...
# 1                                                  }
#                                                    {
# 0      "Information": "Thank you for using Alpha ...
# 1                                                  }
# 0      "Information": "Thank you for using Alpha ...
# 1                                                  }
#                                                    {
# 0      "Information": "Thank you for using Alpha ...
# 1                                                  }
# 0      "Information": "Thank you for using Alpha ...
# 1                                                  }
# 0      "Information": "Thank you for using Alpha ...
# 1                                                  }

# %%
acoes = ['ITUB4', 'ABEV3', 'BBAS3']

compilada = pd.DataFrame()

for acao in acoes:
       url = f'https://www.alphavantage.co/query?function=GLOBAL_QUOTE&symbol={acao}.SAO&apikey={chave_api}&datatype=csv'       
       r = requests.get(url)
       tabela = pd.read_csv(StringIO(r.text))
       lista_tabelas = [compilada, tabela]
       compilada = pd.concat(lista_tabelas)

display(compilada)
# Out:
#                                                    {
# 0      "Information": "Thank you for using Alpha ...
# 1                                                  }
# 0      "Information": "Thank you for using Alpha ...
# 1                                                  }
# 0      "Information": "Thank you for using Alpha ...
# 1                                                  }

# %% [markdown]
# Encontrar Ativos:

# %%
# import matplotlib.pyplot as plt
# plt.figure(figsize=(15, 5))
# plt.plot(data)
# plt.show()
