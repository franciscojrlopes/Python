# %% [markdown]
# API Banco Central
#
# https://dadosabertos.bcb.gov.br/dataset?res_format=API

# %%
import requests

link = 'https://olinda.bcb.gov.br/olinda/servico/mecir_dinheiro_em_circulacao/versao/v1/odata/informacoes_diarias?$top=2000&$format=json&$select=Data,Quantidade,Valor,Denominacao,Especie'

requisição = requests.get(link)
informação = requisição.json()

import pprint
pprint.pprint(informação)
# Out:
# {'@odata.context': 'https://was-p.bcnet.bcb.gov.br/olinda/servico/mecir_dinheiro_em_circulacao/versao/v1/odata$metadata#informacoes_diarias(Data,Quantidade,Valor,Denominacao,Especie)',
#  'value': [{'Data': '1994-10-03',
#             'Denominacao': '0.01',
#             'Especie': 'Moedas',
#             'Quantidade': 692701959,
#             'Valor': 6927019.59},
#            {'Data': '1994-10-03',
#             'Denominacao': '0.05',
#             'Especie': 'Moedas',
#             'Quantidade': 462277579,
#             'Valor': 23113878.95},
#            {'Data': '1994-10-03',
#             'Denominacao': '0.10',
#             'Especie': 'Moedas',
#             'Quantidade': 404559065,
#             'Valor': 40455906.5},
#            {'Data': '1994-10-03',
#             'Denominacao': '0.25',
#             'Especie': 'Moedas',
#             'Quantidade': 1492870,
#             'Valor': 373217.5},
#            {'Data': '1994-10-03',
#             'Denominacao': '0.50',
# ...

# %% [markdown]
# Sem separdor na coluna valor:

# %%
import pandas as pd
tabela = pd.DataFrame(informação['value'])

display(tabela)
# Out:
# C:\Users\fraro\AppData\Local\Temp\ipykernel_9348\1727148633.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#             Data  Quantidade         Valor Denominacao  Especie
# 0     1994-10-03   692701959  6.927020e+06        0.01   Moedas
# 1     1994-10-03   462277579  2.311388e+07        0.05   Moedas
# 2     1994-10-03   404559065  4.045591e+07        0.10   Moedas
# 3     1994-10-03     1492870  3.732175e+05        0.25   Moedas
# 4     1994-10-03   278901842  1.394509e+08        0.50   Moedas
# ...          ...         ...           ...         ...      ...
# ...

# %% [markdown]
# Com separador na coluna valor:

# %%
import pandas as pd
tabela = pd.DataFrame(informação['value'])
# tabela["Valor"] = tabela["Valor"].map("R${:,.2f}".format)
tabela['Valor'] = tabela['Valor'].map('R$ {:,.2f}'.format)
display(tabela)
# Out:
#             Data  Quantidade                Valor Denominacao  Especie
# 0     1994-10-03   692701959      R$ 6,927,019.59        0.01   Moedas
# 1     1994-10-03   462277579     R$ 23,113,878.95        0.05   Moedas
# 2     1994-10-03   404559065     R$ 40,455,906.50        0.10   Moedas
# 3     1994-10-03     1492870        R$ 373,217.50        0.25   Moedas
# 4     1994-10-03   278901842    R$ 139,450,921.00        0.50   Moedas
# ...          ...         ...                  ...         ...      ...
# 1995  1995-06-27   399030343    R$ 199,515,171.50        0.50   Moedas
# 1996  1995-06-27   242557598    R$ 242,557,598.00        1.00  Cédulas
# 1997  1995-06-27   200997572    R$ 200,997,572.00        1.00   Moedas
# 1998  1995-06-27   134535155    R$ 672,675,775.00        5.00  Cédulas
# 1999  1995-06-27   290268476  R$ 2,902,684,760.00       10.00  Cédulas
#
# [2000 rows x 5 columns]

# %%
import requests

link = 'https://olinda.bcb.gov.br/olinda/servico/mecir_dinheiro_em_circulacao/versao/v1/odata/informacoes_diarias?$top=1000&$orderby=Data%20desc&$format=json&$select=Data,Quantidade,Valor,Denominacao,Especie'
requisição = requests.get(link)
informação = requisição.json()
import pprint
pprint.pprint(informação)
# Out:
# {'@odata.context': 'https://was-p.bcnet.bcb.gov.br/olinda/servico/mecir_dinheiro_em_circulacao/versao/v1/odata$metadata#informacoes_diarias(Data,Quantidade,Valor,Denominacao,Especie)',
#  'value': [{'Data': '2024-04-24',
#             'Denominacao': '0.01',
#             'Especie': 'Moedas',
#             'Quantidade': 3191004929,
#             'Valor': 31910049.29},
#            {'Data': '2024-04-24',
#             'Denominacao': '0.05',
#             'Especie': 'Moedas',
#             'Quantidade': 7956183287,
#             'Valor': 397809164.35},
#            {'Data': '2024-04-24',
#             'Denominacao': '0.10',
#             'Especie': 'Moedas',
#             'Quantidade': 8113658459,
#             'Valor': 811365845.9},
#            {'Data': '2024-04-24',
#             'Denominacao': '0.25',
#             'Especie': 'Moedas',
#             'Quantidade': 3648910340,
#             'Valor': 912227585.0},
#            {'Data': '2024-04-24',
# ...

# %%
import pandas as pd
tabela = pd.DataFrame(informação['value'])
# tabela["Valor"] = tabela["Valor"].map("R${:,.2f}".format)
tabela['Valor'] = tabela['Valor'].map('R$ {:,.2f}'.format)
display(tabela)
# Out:
#            Data  Quantidade                Valor Denominacao  Especie
# 0    2024-04-24  3191004929     R$ 31,910,049.29        0.01   Moedas
# 1    2024-04-24  7956183287    R$ 397,809,164.35        0.05   Moedas
# 2    2024-04-24  8113658459    R$ 811,365,845.90        0.10   Moedas
# 3    2024-04-24  3648910340    R$ 912,227,585.00        0.25   Moedas
# 4    2024-04-24  3679562684  R$ 1,839,781,342.00        0.50   Moedas
# ..          ...         ...                  ...         ...      ...
# 995  2024-01-11  7883244732    R$ 394,162,236.60        0.05   Moedas
# 996  2024-01-11  8045848322    R$ 804,584,832.20        0.10   Moedas
# 997  2024-01-11  3610630192    R$ 902,657,548.00        0.25   Moedas
# 998  2024-01-11  3647372643  R$ 1,823,686,321.50        0.50   Moedas
# 999  2024-01-11   148649749    R$ 148,649,749.00        1.00  Cédulas
#
# [1000 rows x 5 columns]

# %%
# Pegar todas as informações com todas requisições:

import requests
import pandas as pd

tabela_final = pd.DataFrame()
pular_indice = 0
while True: #looping infinito

    link = f'https://olinda.bcb.gov.br/olinda/servico/mecir_dinheiro_em_circulacao/versao/v1/odata/informacoes_diarias_com_categoria?$top=10000&$skip={pular_indice}$format=json'

    requisição = requests.get(link)
    informação = requisição.json()
    tabela = pd.DataFrame(informação['value'])
    if len(informação['value']) <1 :
        break
    tabela_final = pd.concat([tabela, tabela_final])
    pular_indice += 10000
display(tabela_final)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\fraro\OneDrive\Documentos\Estudos\Python\.venv\Lib\site-packages\requests\models.py:960, in Response.json(self, **kwargs)
#     959 try:
# --> 960     return complexjson.loads(self.content.decode(encoding), **kwargs)
#     961 except UnicodeDecodeError:
#     962     # Wrong UTF codec detected; usually because it's not UTF-8
#     963     # but some other 8-bit codec.  This is an RFC violation,
#     964     # and the server didn't bother to tell us what codec *was*
#     965     # used.
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
# ...

# %%
import requests
import pandas as pd
link = 'https://olinda.bcb.gov.br/olinda/servico/mecir_dinheiro_em_circulacao/versao/v1/odata/informacoes_diarias_com_categoria?$top=10000&$skip=100000&$format=json'

requisição = requests.get(link)
informação = requisição.json()
print(informação)
# Out:
# {'@odata.context': 'https://was-p.bcnet.bcb.gov.br/olinda/servico/mecir_dinheiro_em_circulacao/versao/v1/odata$metadata#informacoes_diarias_com_categoria', 'value': [{'Data': '2015-07-09', 'Quantidade': 1200131408, 'Valor': 12001314.08, 'Categoria': 'Moedas - 2a. Família', 'Denominacao': '0.01', 'Especie': 'Moedas'}, {'Data': '2015-07-10', 'Quantidade': 1200144408, 'Valor': 12001444.08, 'Categoria': 'Moedas - 2a. Família', 'Denominacao': '0.01', 'Especie': 'Moedas'}, {'Data': '2015-07-10', 'Quantidade': 4476362905, 'Valor': 223818145.25, 'Categoria': 'Moedas - 2a. Família', 'Denominacao': '0.05', 'Especie': 'Moedas'}, {'Data': '2015-07-10', 'Quantidade': 4879045910, 'Valor': 487904591.0, 'Categoria': 'Moedas - 2a. Família', 'Denominacao': '0.10', 'Especie': 'Moedas'}, {'Data': '2015-07-13', 'Quantidade': 18979710, 'Valor': 18979710.0, 'Categoria': 'Moedas - 2a. Família - BC 50 anos', 'Denominacao': '1.00', 'Especie': 'Moedas'}, {'Data': '2015-07-13', 'Quantidade': 8070820, 'Valor': 8
# ...

# %%
import requests

link = 'https://olinda.bcb.gov.br/olinda/servico/mecir_dinheiro_em_circulacao/versao/v1/odata/informacoes_diarias?$top=2000&$format=json&$select=Data,Quantidade,Valor,Denominacao,Especie'
requisição = requests.patch(link, data={'Especie':'Token'})
informação = requisição.json()
import pprint
pprint.pprint(informação)
# Out:
# {'error': 'Forbidden',
#  'message': 'Could not verify the provided CSRF token because your session was '
#             'not found.',
#  'path': '/olinda/servico/mecir_dinheiro_em_circulacao/versao/v1/odata/informacoes_diarias',
#  'status': 403,
#  'timestamp': 1714008405063}

# %%
import requests

link = 'https://olinda.bcb.gov.br/olinda/servico/mecir_dinheiro_em_circulacao/versao/v1/odata/informacoes_diarias?$top=2000&$format=json&$select=Data,Quantidade,Valor,Denominacao,Especie'
requisição = requests.get(link)
informação = requisição.json()
import pprint
pprint.pprint(informação)
# Out:
# {'@odata.context': 'https://was-p.bcnet.bcb.gov.br/olinda/servico/mecir_dinheiro_em_circulacao/versao/v1/odata$metadata#informacoes_diarias(Data,Quantidade,Valor,Denominacao,Especie)',
#  'value': [{'Data': '1994-10-03',
#             'Denominacao': '0.01',
#             'Especie': 'Moedas',
#             'Quantidade': 692701959,
#             'Valor': 6927019.59},
#            {'Data': '1994-10-03',
#             'Denominacao': '0.05',
#             'Especie': 'Moedas',
#             'Quantidade': 462277579,
#             'Valor': 23113878.95},
#            {'Data': '1994-10-03',
#             'Denominacao': '0.10',
#             'Especie': 'Moedas',
#             'Quantidade': 404559065,
#             'Valor': 40455906.5},
#            {'Data': '1994-10-03',
#             'Denominacao': '0.25',
#             'Especie': 'Moedas',
#             'Quantidade': 1492870,
#             'Valor': 373217.5},
#            {'Data': '1994-10-03',
#             'Denominacao': '0.50',
# ...
