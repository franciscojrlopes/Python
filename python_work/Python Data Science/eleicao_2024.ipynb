# %%
import pandas as pd

tabela = pd.read_csv('eleicao_2024_Secoes_RJ.csv')
display(tabela)
# Out:
#      número da Zona,"Nome do local de votação","Município do local de votação","Bairro do local de votação","Endereço do local de votação","CEP do local de votação","Seções instaladas"
# 0     4,"FUNDAÇÃO GETÚLIO VARGAS","RIO DE JANEIRO","...
# 1     4,"COLÉGIO IMACULADA CONCEIÇÃO","RIO DE JANEIR...
# 2     4,"ESCOLA MUNICIPAL PRESIDENTE ARTHUR DA COSTA...
# 3     4,"ESCOLA DINAMIS","RIO DE JANEIRO","BOTAFOGO"...
# 4     4,"ESCOLA MÉXICO","RIO DE JANEIRO","BOTAFOGO",...
# ...                                                 ...
# 4940  256,"CIEP JOSÉ DE DOME - TANGARÁ","CABO FRIO",...
# 4941  256,"ESC. MUN. PROFª. AMÉLIA FERREIRA","CABO F...
# 4942  256,"ESCOLA MUNICIPAL PROFESSORA ANA PEREIRA G...
# 4943  256,"CENTRO EDUC. MUN. PROFª.  MARLI CAPP","CA...
# 4944  256,"ESC. MUN. PALMIRA BESSA DE FIGUEIREDO","C...
#
# [4945 rows x 1 columns]

# %%
tabela = pd.read_excel('xlsx.xlsx')
display(tabela)
# Out:
#                       Exported data  \
# 0     Listagem de Locais de Votação
# 1                    número da Zona
# 2                                 4
# 3                                 4
# 4                                 4
# ...                             ...
# 4942                            256
# 4943                            256
# 4944                            256
# 4945                            256
# 4946                            256
#
#                                              Unnamed: 1  \
# 0                                                   NaN
# 1                              Nome do local de votação
# 2                               FUNDAÇÃO GETÚLIO VARGAS
# 3                           COLÉGIO IMACULADA CONCEIÇÃO
# 4     ESCOLA MUNICIPAL PRESIDENTE ARTHUR DA COSTA E ...
# ...                                                 ...
# 4942                        CIEP JOSÉ DE DOME - TANGARÁ
# 4943                   ESC. MUN. PROFª. AMÉLIA FERREIRA
# ...

# %%
display(tabela.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4947 entries, 0 to 4946
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Exported data  4947 non-null   object
#  1   Unnamed: 1     4946 non-null   object
#  2   Unnamed: 2     4946 non-null   object
#  3   Unnamed: 3     4946 non-null   object
#  4   Unnamed: 4     4946 non-null   object
#  5   Unnamed: 5     4946 non-null   object
#  6   Unnamed: 6     4946 non-null   object
# dtypes: object(7)
# memory usage: 270.7+ KB
# None

# %%
tabela_eleicao = tabela[['Unnamed: 2', 'Unnamed: 6']]
display(tabela_eleicao)
# Out:
#                          Unnamed: 2  \
# 0                               NaN
# 1     Município do local de votação
# 2                    RIO DE JANEIRO
# 3                    RIO DE JANEIRO
# 4                    RIO DE JANEIRO
# ...                             ...
# 4942                      CABO FRIO
# 4943                      CABO FRIO
# 4944                      CABO FRIO
# 4945                      CABO FRIO
# 4946                      CABO FRIO
#
#                                              Unnamed: 6
# 0                                                   NaN
# 1                                     Seções instaladas
# 2     285, 286, 287, 288, 289, 290, 291, 292, 355, 3...
# 3     297, 298, 299, 300, 301, 302, 303, 304, 305, 3...
# 4                               280, 281, 282, 283, 284
# ...                                                 ...
# 4942  104, 105, 106, 107, 108, 109, 110, 111, 112, 1...
# 4943   126, 127, 128, 129, 130, 131, 132, 176, 213, 217
# ...

# %%
df.iloc[[0]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df.iloc[[0]]
#
# NameError: name 'df' is not defined

# %%
a = b = []
a.append(1)
print(b)
# Out:
# [1]
