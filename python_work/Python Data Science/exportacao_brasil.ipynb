# %%
import pandas as pd
tabela = pd.read_csv('exportacoes_franca.csv', encoding=False)
display(tabela)
# Out:
# C:\Users\fraro\AppData\Local\Temp\ipykernel_17524\1349182069.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#         Year  Month Country                         City  SH4 Code  \
# 0       2016      1  France            Águas Mornas - SC       303
# 1       2016      1  France            Águas Mornas - SC       303
# 2       2016      1  France            Águas Mornas - SC       304
# 3       2016      1  France            Águas Mornas - SC       304
# 4       2016      1  France                 Alfenas - MG       901
# ...      ...    ...     ...                          ...       ...
# 142355  2020     12  France                 Vinhedo - SP      8424
# 142356  2020     12  France  Vitória de Santo Antão - PE       714
# 142357  2020     12  France  Vitória de Santo Antão - PE       714
# 142358  2020     12  France                  Xapuri - AC      4409
# 142359  2020     12  France                  Xapuri - AC      4409
#
#                                           SH4 Description  SH2 Code  \
# 0       Fish, frozen, excluding fish fillets and other...         3
# 1       Fish, frozen, excluding fish fillets and other...         3
# 2       Fish fillets and other fish meat (whether or n...         3
# 3       Fish fillets and other fish meat (whether or n...         3
# 4       Coffee, whether or not roasted or decaffeinate...         9
# ...                                                   ...       ...
# 142355  Mechanical appliances (whether or not hand-ope...        84
# 142356  Manioc, arrowroot, salep, Jerusalem artichokes...         7
# 142357  Manioc, arrowroot, salep, Jerusalem artichokes...         7
# 142358  Wood (including strips and friezes for parquet...        44
# 142359  Wood (including strips and friezes for parquet...        44
#
#                                           SH2 Description  \
# 0       Fish and crustaceans, molluscs and other aquat...
# 1       Fish and crustaceans, molluscs and other aquat...
# 2       Fish and crustaceans, molluscs and other aquat...
# 3       Fish and crustaceans, molluscs and other aquat...
# 4                            Coffee, tea, maté and spices
# ...                                                   ...
# 142355  Nuclear reactors, boilers, machinery and mecha...
# 142356     Edible vegetables and certain roots and tubers
# 142357     Edible vegetables and certain roots and tubers
# 142358           Wood and articles of wood; wood charcoal
# 142359           Wood and articles of wood; wood charcoal
#
#              Economic Block  US$ FOB  Net Weight
# 0                    Europe    79360       14150
# 1       European Union (EU)    79360       14150
# 2                    Europe    69412        9385
# 3       European Union (EU)    69412        9385
# 4                    Europe   180914       57600
# ...                     ...      ...         ...
# 142355  European Union (EU)     2316           4
# 142356               Europe    27060       26400
# 142357  European Union (EU)    27060       26400
# 142358               Europe    31111       23045
# 142359  European Union (EU)    31111       23045
#
# [142360 rows x 11 columns]

# %% [markdown]
# Quantas linhas têm a tabela? Existe algum valor vazio que deveria ser tratado? Usar display com info().....

# %%
display(tabela.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142360 entries, 0 to 142359
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Year             142360 non-null  int64
#  1   Month            142360 non-null  int64
#  2   Country          142360 non-null  object
#  3   City             142360 non-null  object
#  4   SH4 Code         142360 non-null  int64
#  5   SH4 Description  142360 non-null  object
#  6   SH2 Code         142360 non-null  int64
#  7   SH2 Description  142360 non-null  object
#  8   Economic Block   142360 non-null  object
#  9   US$ FOB          142360 non-null  int64
#  10  Net Weight       142360 non-null  int64
# dtypes: int64(6), object(5)
# memory usage: 11.9+ MB
# None

# %% [markdown]
# Como foi a evolução das exportações para a frança ao longo dos anos?
# "Crie uma tabela com os anos de 2016, 2017, 2018, 2019 e 2020 e o valor US$ de exportações"

# %%
tabela_anos_exportacao = tabela[['Year', 'US$ FOB']]
display(tabela_anos_exportacao)
# Out:
#         Year  US$ FOB
# 0       2016    79360
# 1       2016    79360
# 2       2016    69412
# 3       2016    69412
# 4       2016   180914
# ...      ...      ...
# 142355  2020     2316
# 142356  2020    27060
# 142357  2020    27060
# 142358  2020    31111
# 142359  2020    31111
#
# [142360 rows x 2 columns]

# %%
tabela_anos_exportacao = tabela[['Year', 'US$ FOB']].groupby('Year').sum()
display(tabela_anos_exportacao)
# Anos somados..............
# Out:
#          US$ FOB
# Year
# 2016  4615500082
# 2017  4448705456
# 2018  5239424416
# 2019  5218723612
# 2020  3967594810

# %%
tabela_anos_exportacao = tabela.groupby('Year').sum()
display(tabela_anos_exportacao)
# Out:
#        Month                                            Country  \
# Year
# 2016  175210  FranceFranceFranceFranceFranceFranceFranceFran...
# 2017  170098  FranceFranceFranceFranceFranceFranceFranceFran...
# 2018  185248  FranceFranceFranceFranceFranceFranceFranceFran...
# 2019  210812  FranceFranceFranceFranceFranceFranceFranceFran...
# 2020  197058  FranceFranceFranceFranceFranceFranceFranceFran...
#
#                                                    City   SH4 Code  \
# Year
# 2016  Águas Mornas - SCÁguas Mornas - SCÁguas Mornas...  169175582
# 2017  Albertina - MGAlbertina - MGAlfenas - MGAlfena...  166934928
# 2018  Alfenas - MGAlfenas - MGAlta Floresta - MTAlta...  171427598
# 2019  Alfenas - MGAlfenas - MGAlta Floresta - MTAlta...  198546658
# 2020  Abaetetuba - PAAbaetetuba - PAAguaí - SPAguaí ...  172155036
#
#                                         SH4 Description  SH2 Code  \
# Year
# 2016  Fish, frozen, excluding fish fillets and other...   1686892
# 2017  Coffee, whether or not roasted or decaffeinate...   1664620
# 2018  Coffee, whether or not roasted or decaffeinate...   1709336
# 2019  Coffee, whether or not roasted or decaffeinate...   1979926
# 2020  Fruit, nuts and other edible parts of plants, ...   1716784
#
#                                         SH2 Description  \
# Year
# 2016  Fish and crustaceans, molluscs and other aquat...
# 2017  Coffee, tea, maté and spicesCoffee, tea, maté ...
# 2018  Coffee, tea, maté and spicesCoffee, tea, maté ...
# 2019  Coffee, tea, maté and spicesCoffee, tea, maté ...
# 2020  Preparations of vegetables, fruit, nuts or oth...
#
#                                          Economic Block     US$ FOB  \
# Year
# 2016  EuropeEuropean Union (EU)EuropeEuropean Union ...  4615500082
# 2017  EuropeEuropean Union (EU)EuropeEuropean Union ...  4448705456
# 2018  EuropeEuropean Union (EU)EuropeEuropean Union ...  5239424416
# 2019  EuropeEuropean Union (EU)EuropeEuropean Union ...  5218723612
# 2020  EuropeEuropean Union (EU)EuropeEuropean Union ...  3967594810
#
#        Net Weight
# Year
# 2016  21798116518
# 2017  22556529252
# 2018  20905240132
# 2019  16412415350
# 2020  10868888048

# %%
tabela_anos_exportacao = tabela[['Year', 'US$ FOB']]
display(tabela_anos_exportacao)
# Out:
#         Year  US$ FOB
# 0       2016    79360
# 1       2016    79360
# 2       2016    69412
# 3       2016    69412
# 4       2016   180914
# ...      ...      ...
# 142355  2020     2316
# 142356  2020    27060
# 142357  2020    27060
# 142358  2020    31111
# 142359  2020    31111
#
# [142360 rows x 2 columns]

# %%
tabela_anos_exportacao = tabela[['Year', 'US$ FOB']].groupby('Year')
display(tabela_anos_exportacao)

# %%
tabela_anos_exportacao = tabela.groupby('Year').sum(numeric_only=True)
tabela_anos_exportacao -= tabela_anos_exportacao[['US$ FOB']]

display(tabela_anos_exportacao)
# Out:
#       Month  SH4 Code  SH2 Code  US$ FOB  Net Weight
# Year
# 2016    NaN       NaN       NaN        0         NaN
# 2017    NaN       NaN       NaN        0         NaN
# 2018    NaN       NaN       NaN        0         NaN
# 2019    NaN       NaN       NaN        0         NaN
# 2020    NaN       NaN       NaN        0         NaN

# %%
tabela_anos_exportacao = tabela.groupby('Year').sum(numeric_only=True)
tabela_anos_exportacao -= tabela_anos_exportacao[['US$ FOB']]

# %%
tabela_anos_exportacao = tabela[['Year', 'US$ FOB']]
display(tabela_anos_exportacao)
# Out:
#         Year  US$ FOB
# 0       2016    79360
# 1       2016    79360
# 2       2016    69412
# 3       2016    69412
# 4       2016   180914
# ...      ...      ...
# 142355  2020     2316
# 142356  2020    27060
# 142357  2020    27060
# 142358  2020    31111
# 142359  2020    31111
#
# [142360 rows x 2 columns]

# %% [markdown]
# Quais os produtos mais exportados ao longo de todo o período?
# "Queremos saber os produtos com maior valor US$ de exportação"
